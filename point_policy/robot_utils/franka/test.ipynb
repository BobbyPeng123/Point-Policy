# %% [markdown]
# Script to label object points.
#
# Adapted from P3PO - [link](https://github.com/mlevy2525/P3PO/blob/main/p3po/data_generation/label_points.ipynb)

# %%
import pickle

pkl_path = "/home/bobby/data/expert_demos/franka_env/0302_pick_bottle.pkl"

with open(pkl_path, "rb") as f:
    data = pickle.load(f)

print(data.keys())  # Check available keys
print(len(data.get("observations", [])))  # Check if observations exist
print(data['observations'])
# Out:
# dict_keys(['observations', 'max_cartesian', 'min_cartesian', 'max_gripper', 'min_gripper'])
# 20
# [{'pixels1': array([[[[122, 177,  89],
#          [123, 178,  90],
#          [126, 180,  93],
#          ...,
#          [149, 167, 181],
#          [147, 168, 179],
#          [147, 169, 179]],
#
#         [[123, 178,  90],
#          [122, 176,  90],
#          [121, 175,  89],
#          ...,
#          [149, 167, 181],
#          [147, 168, 179],
#          [147, 169, 179]],
#
#         [[123, 176,  93],
#          [122, 175,  92],
#          [120, 173,  91],
#          ...,
#          [149, 167, 181],
#          [147, 168, 179],
#          [147, 169, 179]],
#
#         ...,
#
#         [[100,  58,   6],
#          [100,  58,   6],
#          [100,  58,   6],
#          ...,
#          [ 46,  35,  25],
#          [ 39,  32,  20],
#          [ 60,  54,  42]],
#
#         [[100,  58,   6],
#          [100,  58,   6],
#          [100,  58,   6],
#          ...,
# ...

# %%
# Print a sample observation
for i in range(20):
    sample_observation = data['observations'][i]  # Get the first observation
    # print(sample_observation)
    print(f"Total number of frames in observation: {len(sample_observation)}")
# Out:
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 10
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
# Total number of frames in observation: 16
